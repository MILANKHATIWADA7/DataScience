# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('dm_office_sales.csv')

# %%
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
sns.rugplot(data = df, x = 'salary')
# Out:
# <Axes: xlabel='salary'>

# %%
len(df.salary.unique())
# Out:
# 993

# %%
len(df)
# Out:
# 1000

# %%
plt.figure(figsize=(15,3))
sns.rugplot(data = df, x = 'salary', height =0.50)
# Out:
# <Axes: xlabel='salary'>

# %%
#rugplot doesnot concern y-axis
sns.rugplot(data = df, x = 'salary', height =0.50)
# Out:
# <Axes: xlabel='salary'>

# %%
plt.figure(figsize=(12,4), dpi=150)
sns.rugplot(data = df, x = 'salary', height =0.50)
# Out:
# <Axes: xlabel='salary'>

# %%
#displot = distributtion plot
sns.displot(data = df, x = 'salary', bins= 100);

# %%
sns.displot(data = df, x = 'salary', bins= 10);

# %%
#sns.set_style('tickle')
plt.figure(dpi=150)
sns.displot(data = df, x = 'salary', color='red',edgecolor='purple', bins= 20, kde=True, linewidth=2);

# %%
df['salary']
# Out:
# 0       91684
# 1      119679
# 2       82045
# 3       92949
# 4       71280
#         ...
# 995     70083
# 996     68648
# 997    108354
# 998     79035
# 999    108444
# Name: salary, Length: 1000, dtype: int64

# %%
plt.figure(figsize=(12,4), dpi=150)
sns.histplot(data=df, x='salary');

# %%
sns.kdeplot(data=df, x='salary')
# Out:
# <Axes: xlabel='salary', ylabel='Density'>

# %%
df.columns
# Out:
# Index(['division', 'level of education', 'training level', 'work experience',
#        'salary', 'sales'],
#       dtype='object')

# %%
df['division'].value_counts()
# Out:
# office supplies      252
# printers             250
# peripherals          243
# computer hardware    159
# computer software     96
# Name: division, dtype: int64

# %%
df['division'].value_counts().sum()
# Out:
# 1000

# %%
#color=['red','green','blue','yellow','black']
plt.figure(figsize=(15,8), dpi=150)
sns.countplot(df, x='division')
# Out:
# <Axes: xlabel='division', ylabel='count'>

# %%
plt.figure(figsize=(10,8))
sns.countplot(df, x= 'level of education')
# Out:
# <Axes: xlabel='level of education', ylabel='count'>

# %%
sns.countplot(df, x= 'level of education', hue='division')
# Out:
# <Axes: xlabel='level of education', ylabel='count'>

# %%
df.columns
# Out:
# Index(['division', 'level of education', 'training level', 'work experience',
#        'salary', 'sales'],
#       dtype='object')

# %%
df['training level']
# Out:
# 0      2
# 1      2
# 2      0
# 3      2
# 4      1
#       ..
# 995    1
# 996    1
# 997    2
# 998    2
# 999    0
# Name: training level, Length: 1000, dtype: int64

# %%
sns.countplot(df, x= 'level of education', hue='training level')
# Out:
# <Axes: xlabel='level of education', ylabel='count'>

# %%
sns.barplot(data=df, x= 'level of education', y='salary')
# Out:
# <Axes: xlabel='level of education', ylabel='salary'>
